# %%
import numpy as np
import os
import random
import pickle
import matplotlib.pyplot as plt
import cv2
import time

DATADIR = "C:\\Users\\Asia\\data1\\train"

CATEGORIES = ["diabetic_retinopathy", "glaucoma", "healthy" ]

for category in CATEGORIES :
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        break
    break
#print(img_array)
#print(img_array.shape)


IMG_SIZE = 50
training_data = []

def create_training_data():
    for category in CATEGORIES :
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try :
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                output = cv2.medianBlur(new_array, 5)
                th2 = cv2.adaptiveThreshold(output,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY_INV,11,2)
                training_data.append([th2, class_num])
            except Exception as e:
                pass

create_training_data()

random.shuffle(training_data)

X = [] 
y = [] 


for features, label in training_data:
    X.append(features)
    y.append(label)

X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

pickle_out = open("X1.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y1.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

pickle_in = open("X1.pickle", "rb")
X = pickle.load(pickle_in)

pickle_in = open("y1.pickle","rb")
y = pickle.load(pickle_in)
###########################################
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
from keras.models import model_from_json
from keras.models import load_model
import time

start_time = time.time()
X = pickle.load(open("X1.pickle", "rb"))
y = pickle.load(open("y1.pickle", "rb"))


X = X/255.0
y = np.array(y)

model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape = X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

model.add(Dense(3))
model.add(Activation("relu"))

model.add(Dense(3))
model.add(Activation("softmax"))


model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])


history = model.fit(X, y, batch_size=64, epochs=100, validation_split=0.2)
#batch 32 lub 64
#epoch 100, 500, 1000

model_json = model.to_json()
with open("model.json", "w") as json_file :
    json_file.write(model_json)

model.save_weights("model.h5")
print("Saved model to disk")

model.save('CNN.model')
print(history.history.keys())
plt.figure(1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.figure(2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
elapsed_time = time.time() - start_time
time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 157ms/step - loss: 1.1040 - accuracy: 0.3083 - val_loss: 1.0990 - val_accuracy: 0.2459
# Epoch 2/100
# 4/4 [==============================] - 0s 87ms/step - loss: 1.0985 - accuracy: 0.3583 - val_loss: 1.1000 - val_accuracy: 0.2131
# Epoch 3/100
# 4/4 [==============================] - 0s 93ms/step - loss: 1.0982 - accuracy: 0.3667 - val_loss: 1.1007 - val_accuracy: 0.2131
# Epoch 4/100
# 4/4 [==============================] - 0s 93ms/step - loss: 1.0980 - accuracy: 0.3667 - val_loss: 1.1015 - val_accuracy: 0.2131
# Epoch 5/100
# 4/4 [==============================] - 0s 91ms/step - loss: 1.0979 - accuracy: 0.3667 - val_loss: 1.1022 - val_accuracy: 0.2131
# Epoch 6/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0977 - accuracy: 0.3667 - val_loss: 1.1029 - val_accuracy: 0.2131
# Epoch 7/100
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0975 - accuracy: 0.3667 - val_loss: 1.1034 - val_accuracy: 0.2131
# Epoch 8/100
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0974 - accuracy: 0.3667 - val_loss: 1.1040 - val_accuracy: 0.2131
# Epoch 9/100
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0973 - accuracy: 0.3667 - val_loss: 1.1045 - val_accuracy: 0.2131
# Epoch 10/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0972 - accuracy: 0.3667 - val_loss: 1.1050 - val_accuracy: 0.2131
# Epoch 11/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0971 - accuracy: 0.3667 - val_loss: 1.1055 - val_accuracy: 0.2131
# Epoch 12/100
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0970 - accuracy: 0.3667 - val_loss: 1.1061 - val_accuracy: 0.2131
# Epoch 13/100
# 4/4 [==============================] - 0s 91ms/step - loss: 1.0969 - accuracy: 0.3667 - val_loss: 1.1066 - val_accuracy: 0.2131
# Epoch 14/100
# 4/4 [==============================] - 0s 91ms/step - loss: 1.0968 - accuracy: 0.3667 - val_loss: 1.1071 - val_accuracy: 0.2131
# Epoch 15/100
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0968 - accuracy: 0.3667 - val_loss: 1.1077 - val_accuracy: 0.2131
# Epoch 16/100
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0966 - accuracy: 0.3667 - val_loss: 1.1082 - val_accuracy: 0.2131
# Epoch 17/100
# 4/4 [==============================] - 0s 93ms/step - loss: 1.0966 - accuracy: 0.3667 - val_loss: 1.1087 - val_accuracy: 0.2131
# Epoch 18/100
# 4/4 [==============================] - 0s 93ms/step - loss: 1.0964 - accuracy: 0.3667 - val_loss: 1.1091 - val_accuracy: 0.2131
# Epoch 19/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0964 - accuracy: 0.3667 - val_loss: 1.1096 - val_accuracy: 0.2131
# Epoch 20/100
# 4/4 [==============================] - 0s 92ms/step - loss: 1.0963 - accuracy: 0.3667 - val_loss: 1.1101 - val_accuracy: 0.2131
# Epoch 21/100
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0962 - accuracy: 0.3667 - val_loss: 1.1106 - val_accuracy: 0.2131
# Epoch 22/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0962 - accuracy: 0.3667 - val_loss: 1.1111 - val_accuracy: 0.2131
# Epoch 23/100
# 4/4 [==============================] - 0s 94ms/step - loss: 1.0961 - accuracy: 0.3667 - val_loss: 1.1116 - val_accuracy: 0.2131
# Epoch 24/100
# 4/4 [==============================] - 0s 94ms/step - loss: 1.0960 - accuracy: 0.3667 - val_loss: 1.1119 - val_accuracy: 0.2131
# Epoch 25/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0960 - accuracy: 0.3667 - val_loss: 1.1123 - val_accuracy: 0.2131
# Epoch 26/100
# 4/4 [==============================] - 0s 91ms/step - loss: 1.0959 - accuracy: 0.3667 - val_loss: 1.1126 - val_accuracy: 0.2131
# Epoch 27/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0959 - accuracy: 0.3667 - val_loss: 1.1129 - val_accuracy: 0.2131
# Epoch 28/100
# 4/4 [==============================] - 0s 93ms/step - loss: 1.0959 - accuracy: 0.3667 - val_loss: 1.1133 - val_accuracy: 0.2131
# Epoch 29/100
# 4/4 [==============================] - 0s 95ms/step - loss: 1.0958 - accuracy: 0.3667 - val_loss: 1.1135 - val_accuracy: 0.2131
# Epoch 30/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0958 - accuracy: 0.3667 - val_loss: 1.1139 - val_accuracy: 0.2131
# Epoch 31/100
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0957 - accuracy: 0.3667 - val_loss: 1.1143 - val_accuracy: 0.2131
# Epoch 32/100
# 4/4 [==============================] - 0s 99ms/step - loss: 1.0957 - accuracy: 0.3667 - val_loss: 1.1146 - val_accuracy: 0.2131
# Epoch 33/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0957 - accuracy: 0.3667 - val_loss: 1.1151 - val_accuracy: 0.2131
# Epoch 34/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0956 - accuracy: 0.3667 - val_loss: 1.1154 - val_accuracy: 0.2131
# Epoch 35/100
# 4/4 [==============================] - 0s 93ms/step - loss: 1.0956 - accuracy: 0.3667 - val_loss: 1.1157 - val_accuracy: 0.2131
# Epoch 36/100
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0955 - accuracy: 0.3667 - val_loss: 1.1160 - val_accuracy: 0.2131
# Epoch 37/100
# 4/4 [==============================] - 0s 101ms/step - loss: 1.0955 - accuracy: 0.3667 - val_loss: 1.1163 - val_accuracy: 0.2131
# Epoch 38/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0955 - accuracy: 0.3667 - val_loss: 1.1166 - val_accuracy: 0.2131
# Epoch 39/100
# 4/4 [==============================] - 0s 124ms/step - loss: 1.0954 - accuracy: 0.3667 - val_loss: 1.1171 - val_accuracy: 0.2131
# Epoch 40/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0954 - accuracy: 0.3667 - val_loss: 1.1174 - val_accuracy: 0.2131
# Epoch 41/100
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0954 - accuracy: 0.3667 - val_loss: 1.1177 - val_accuracy: 0.2131
# Epoch 42/100
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0953 - accuracy: 0.3667 - val_loss: 1.1180 - val_accuracy: 0.2131
# Epoch 43/100
# 4/4 [==============================] - 0s 95ms/step - loss: 1.0953 - accuracy: 0.3667 - val_loss: 1.1183 - val_accuracy: 0.2131
# Epoch 44/100
# 4/4 [==============================] - 0s 108ms/step - loss: 1.0953 - accuracy: 0.3667 - val_loss: 1.1187 - val_accuracy: 0.2131
# Epoch 45/100
# 4/4 [==============================] - 0s 117ms/step - loss: 1.0953 - accuracy: 0.3667 - val_loss: 1.1190 - val_accuracy: 0.2131
# Epoch 46/100
# 4/4 [==============================] - 0s 108ms/step - loss: 1.0952 - accuracy: 0.3667 - val_loss: 1.1193 - val_accuracy: 0.2131
# Epoch 47/100
# 4/4 [==============================] - 0s 123ms/step - loss: 1.0952 - accuracy: 0.3667 - val_loss: 1.1196 - val_accuracy: 0.2131
# Epoch 48/100
# 4/4 [==============================] - 0s 93ms/step - loss: 1.0952 - accuracy: 0.3667 - val_loss: 1.1199 - val_accuracy: 0.2131
# Epoch 49/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0952 - accuracy: 0.3667 - val_loss: 1.1202 - val_accuracy: 0.2131
# Epoch 50/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0951 - accuracy: 0.3667 - val_loss: 1.1204 - val_accuracy: 0.2131
# Epoch 51/100
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0951 - accuracy: 0.3667 - val_loss: 1.1207 - val_accuracy: 0.2131
# Epoch 52/100
# 4/4 [==============================] - 0s 88ms/step - loss: 1.0951 - accuracy: 0.3667 - val_loss: 1.1211 - val_accuracy: 0.2131
# Epoch 53/100
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0951 - accuracy: 0.3667 - val_loss: 1.1213 - val_accuracy: 0.2131
# Epoch 54/100
# 4/4 [==============================] - 0s 92ms/step - loss: 1.0951 - accuracy: 0.3667 - val_loss: 1.1216 - val_accuracy: 0.2131
# Epoch 55/100
# 4/4 [==============================] - 0s 91ms/step - loss: 1.0951 - accuracy: 0.3667 - val_loss: 1.1218 - val_accuracy: 0.2131
# Epoch 56/100
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0950 - accuracy: 0.3667 - val_loss: 1.1220 - val_accuracy: 0.2131
# Epoch 57/100
# 4/4 [==============================] - 0s 101ms/step - loss: 1.0951 - accuracy: 0.3667 - val_loss: 1.1223 - val_accuracy: 0.2131
# Epoch 58/100
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0950 - accuracy: 0.3667 - val_loss: 1.1225 - val_accuracy: 0.2131
# Epoch 59/100
# 4/4 [==============================] - 0s 98ms/step - loss: 1.0950 - accuracy: 0.3667 - val_loss: 1.1228 - val_accuracy: 0.2131
# Epoch 60/100
# 4/4 [==============================] - 0s 103ms/step - loss: 1.0950 - accuracy: 0.3667 - val_loss: 1.1231 - val_accuracy: 0.2131
# Epoch 61/100
# 4/4 [==============================] - 0s 111ms/step - loss: 1.0950 - accuracy: 0.3667 - val_loss: 1.1233 - val_accuracy: 0.2131
# Epoch 62/100
# 4/4 [==============================] - 0s 113ms/step - loss: 1.0950 - accuracy: 0.3667 - val_loss: 1.1233 - val_accuracy: 0.2131
# Epoch 63/100
# 4/4 [==============================] - 1s 126ms/step - loss: 1.0950 - accuracy: 0.3667 - val_loss: 1.1235 - val_accuracy: 0.2131
# Epoch 64/100
# 4/4 [==============================] - 1s 130ms/step - loss: 1.0950 - accuracy: 0.3667 - val_loss: 1.1237 - val_accuracy: 0.2131
# Epoch 65/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0950 - accuracy: 0.3667 - val_loss: 1.1239 - val_accuracy: 0.2131
# Epoch 66/100
# 4/4 [==============================] - 0s 95ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1240 - val_accuracy: 0.2131
# Epoch 67/100
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1241 - val_accuracy: 0.2131
# Epoch 68/100
# 4/4 [==============================] - 0s 111ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1243 - val_accuracy: 0.2131
# Epoch 69/100
# 4/4 [==============================] - 0s 105ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1244 - val_accuracy: 0.2131
# Epoch 70/100
# 4/4 [==============================] - 0s 92ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1245 - val_accuracy: 0.2131
# Epoch 71/100
# 4/4 [==============================] - 0s 98ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1247 - val_accuracy: 0.2131
# Epoch 72/100
# 4/4 [==============================] - 0s 103ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1248 - val_accuracy: 0.2131
# Epoch 73/100
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1249 - val_accuracy: 0.2131
# Epoch 74/100
# 4/4 [==============================] - 0s 102ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1251 - val_accuracy: 0.2131
# Epoch 75/100
# 4/4 [==============================] - 0s 99ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1253 - val_accuracy: 0.2131
# Epoch 76/100
# 4/4 [==============================] - 0s 98ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1254 - val_accuracy: 0.2131
# Epoch 77/100
# 4/4 [==============================] - 0s 91ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1257 - val_accuracy: 0.2131
# Epoch 78/100
# 4/4 [==============================] - 0s 95ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1259 - val_accuracy: 0.2131
# Epoch 79/100
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1259 - val_accuracy: 0.2131
# Epoch 80/100
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1260 - val_accuracy: 0.2131
# Epoch 81/100
# 4/4 [==============================] - 0s 109ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1261 - val_accuracy: 0.2131
# Epoch 82/100
# 4/4 [==============================] - 0s 101ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1262 - val_accuracy: 0.2131
# Epoch 83/100
# 4/4 [==============================] - 0s 98ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1263 - val_accuracy: 0.2131
# Epoch 84/100
# 4/4 [==============================] - 0s 92ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1264 - val_accuracy: 0.2131
# Epoch 85/100
# 4/4 [==============================] - 0s 91ms/step - loss: 1.0949 - accuracy: 0.3667 - val_loss: 1.1266 - val_accuracy: 0.2131
# Epoch 86/100
# 4/4 [==============================] - 0s 95ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1267 - val_accuracy: 0.2131
# Epoch 87/100
# 4/4 [==============================] - 1s 136ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1268 - val_accuracy: 0.2131
# Epoch 88/100
# 4/4 [==============================] - 0s 87ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1268 - val_accuracy: 0.2131
# Epoch 89/100
# 4/4 [==============================] - 0s 98ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1270 - val_accuracy: 0.2131
# Epoch 90/100
# 4/4 [==============================] - 0s 94ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1272 - val_accuracy: 0.2131
# Epoch 91/100
# 4/4 [==============================] - 0s 101ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1273 - val_accuracy: 0.2131
# Epoch 92/100
# 4/4 [==============================] - 0s 87ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1274 - val_accuracy: 0.2131
# Epoch 93/100
# 4/4 [==============================] - 0s 103ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1275 - val_accuracy: 0.2131
# Epoch 94/100
# 4/4 [==============================] - 0s 91ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1275 - val_accuracy: 0.2131
# Epoch 95/100
# 4/4 [==============================] - 0s 99ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1277 - val_accuracy: 0.2131
# Epoch 96/100
# 4/4 [==============================] - 0s 94ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1278 - val_accuracy: 0.2131
# Epoch 97/100
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1277 - val_accuracy: 0.2131
# Epoch 98/100
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1278 - val_accuracy: 0.2131
# Epoch 99/100
# 4/4 [==============================] - 0s 111ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1279 - val_accuracy: 0.2131
# Epoch 100/100
# 4/4 [==============================] - 0s 107ms/step - loss: 1.0948 - accuracy: 0.3667 - val_loss: 1.1281 - val_accuracy: 0.2131
# Saved model to disk
# INFO:tensorflow:Assets written to: CNN.model\assets
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# '00:00:52'

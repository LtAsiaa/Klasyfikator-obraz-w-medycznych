# %%
import numpy as np
import os
import random
import pickle
import matplotlib.pyplot as plt
import cv2


#DATADIR = "chest_xray\\train"

#CATEGORIES = ["NORMAL", "PNEUMONIA"]

DATADIR = "C:\\Users\\Asia\\data1\\train"

CATEGORIES = ["diabetic_retinopathy", "glaucoma", "healthy"]

for category in CATEGORIES :
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        break
    break
#print(img_array)
#print(img_array.shape)


IMG_SIZE = 50
training_data = []

def create_training_data():
    for category in CATEGORIES :
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try :
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                output = cv2.medianBlur(new_array, 5)
                th2 = cv2.adaptiveThreshold(output,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY_INV,7,2)
                training_data.append([th2, class_num])
            except Exception as e:
                pass

create_training_data()

random.shuffle(training_data)

X = [] 
y = [] 


for features, label in training_data:
    X.append(features)
    y.append(label)

X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

pickle_out = open("X1.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y1.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

pickle_in = open("X1.pickle", "rb")
X = pickle.load(pickle_in)

pickle_in = open("y1.pickle","rb")
y = pickle.load(pickle_in)
###########################################
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
from keras.models import model_from_json
from keras.models import load_model
import time 

start_time = time.time()
X = pickle.load(open("X1.pickle", "rb"))
y = pickle.load(open("y1.pickle", "rb"))


X = X/255.0
y = np.array(y)

model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape = X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

model.add(Dense(3))
model.add(Activation("relu"))

model.add(Dense(3))
model.add(Activation("softmax"))


model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])


history = model.fit(X, y, batch_size=64, epochs=100, validation_split=0.2)
#history = model.fit(X, y, batch_size=16, epochs=40, validation_split=0.2)
#history = model.fit(X, y, batch_size=2, epochs=100, validation_split=0.2)

model_json = model.to_json()
with open("model.json", "w") as json_file :
    json_file.write(model_json)

model.save_weights("model.h5")
print("Saved model to disk")

model.save('CNN.model')
print(history.history.keys())
plt.figure(1)
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')

plt.figure(2)
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
elapsed_time = time.time() - start_time
time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 144ms/step - loss: 1.0969 - accuracy: 0.3542 - val_loss: 1.1010 - val_accuracy: 0.2787
# Epoch 2/100
# 4/4 [==============================] - 0s 123ms/step - loss: 1.0993 - accuracy: 0.3500 - val_loss: 1.1006 - val_accuracy: 0.2787
# Epoch 3/100
# 4/4 [==============================] - 1s 127ms/step - loss: 1.0865 - accuracy: 0.4083 - val_loss: 1.1010 - val_accuracy: 0.3770
# Epoch 4/100
# 4/4 [==============================] - 0s 123ms/step - loss: 1.0820 - accuracy: 0.4583 - val_loss: 1.1089 - val_accuracy: 0.2459
# Epoch 5/100
# 4/4 [==============================] - 1s 132ms/step - loss: 1.0663 - accuracy: 0.4583 - val_loss: 1.1151 - val_accuracy: 0.2459
# Epoch 6/100
# 4/4 [==============================] - 0s 118ms/step - loss: 1.0500 - accuracy: 0.4792 - val_loss: 1.1221 - val_accuracy: 0.2459
# Epoch 7/100
# 4/4 [==============================] - 0s 122ms/step - loss: 1.0371 - accuracy: 0.4625 - val_loss: 1.1314 - val_accuracy: 0.3443
# Epoch 8/100
# 4/4 [==============================] - 1s 141ms/step - loss: 1.0157 - accuracy: 0.4833 - val_loss: 1.1302 - val_accuracy: 0.2623
# Epoch 9/100
# 4/4 [==============================] - 1s 132ms/step - loss: 0.9986 - accuracy: 0.5083 - val_loss: 1.1191 - val_accuracy: 0.3115
# Epoch 10/100
# 4/4 [==============================] - 1s 130ms/step - loss: 0.9636 - accuracy: 0.5417 - val_loss: 1.1046 - val_accuracy: 0.3934
# Epoch 11/100
# 4/4 [==============================] - 0s 112ms/step - loss: 0.9753 - accuracy: 0.5208 - val_loss: 1.1223 - val_accuracy: 0.2951
# Epoch 12/100
# 4/4 [==============================] - 1s 130ms/step - loss: 0.9496 - accuracy: 0.5250 - val_loss: 1.0905 - val_accuracy: 0.3770
# Epoch 13/100
# 4/4 [==============================] - 0s 123ms/step - loss: 0.9327 - accuracy: 0.5208 - val_loss: 1.1100 - val_accuracy: 0.4098
# Epoch 14/100
# 4/4 [==============================] - 1s 130ms/step - loss: 0.9565 - accuracy: 0.4958 - val_loss: 1.0799 - val_accuracy: 0.3607
# Epoch 15/100
# 4/4 [==============================] - 1s 127ms/step - loss: 0.9142 - accuracy: 0.5583 - val_loss: 1.0768 - val_accuracy: 0.3607
# Epoch 16/100
# 4/4 [==============================] - 0s 101ms/step - loss: 0.9038 - accuracy: 0.5500 - val_loss: 1.1063 - val_accuracy: 0.3607
# Epoch 17/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.8384 - accuracy: 0.5917 - val_loss: 1.1011 - val_accuracy: 0.3279
# Epoch 18/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.8320 - accuracy: 0.5958 - val_loss: 1.0886 - val_accuracy: 0.3934
# Epoch 19/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.7847 - accuracy: 0.6083 - val_loss: 1.0904 - val_accuracy: 0.3279
# Epoch 20/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.7579 - accuracy: 0.6375 - val_loss: 1.0994 - val_accuracy: 0.4098
# Epoch 21/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.7139 - accuracy: 0.6458 - val_loss: 1.0826 - val_accuracy: 0.3770
# Epoch 22/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.6737 - accuracy: 0.6750 - val_loss: 1.0768 - val_accuracy: 0.4262
# Epoch 23/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.6470 - accuracy: 0.6917 - val_loss: 1.0694 - val_accuracy: 0.3934
# Epoch 24/100
# 4/4 [==============================] - 0s 97ms/step - loss: 0.6136 - accuracy: 0.7125 - val_loss: 1.0979 - val_accuracy: 0.3934
# Epoch 25/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.5799 - accuracy: 0.7667 - val_loss: 1.1181 - val_accuracy: 0.3770
# Epoch 26/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.5433 - accuracy: 0.7917 - val_loss: 1.0611 - val_accuracy: 0.4426
# Epoch 27/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.5112 - accuracy: 0.8083 - val_loss: 1.1894 - val_accuracy: 0.4590
# Epoch 28/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.4992 - accuracy: 0.8167 - val_loss: 1.2585 - val_accuracy: 0.4098
# Epoch 29/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.5284 - accuracy: 0.7458 - val_loss: 1.1309 - val_accuracy: 0.4590
# Epoch 30/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.4219 - accuracy: 0.8583 - val_loss: 1.1804 - val_accuracy: 0.4262
# Epoch 31/100
# 4/4 [==============================] - 0s 93ms/step - loss: 0.4026 - accuracy: 0.8792 - val_loss: 1.1981 - val_accuracy: 0.4262
# Epoch 32/100
# 4/4 [==============================] - 0s 90ms/step - loss: 0.3915 - accuracy: 0.9042 - val_loss: 1.2383 - val_accuracy: 0.4262
# Epoch 33/100
# 4/4 [==============================] - 0s 94ms/step - loss: 0.3536 - accuracy: 0.9083 - val_loss: 1.3056 - val_accuracy: 0.4262
# Epoch 34/100
# 4/4 [==============================] - 0s 91ms/step - loss: 0.3159 - accuracy: 0.9250 - val_loss: 1.4780 - val_accuracy: 0.3934
# Epoch 35/100
# 4/4 [==============================] - 0s 101ms/step - loss: 0.3486 - accuracy: 0.8792 - val_loss: 1.4714 - val_accuracy: 0.4426
# Epoch 36/100
# 4/4 [==============================] - 0s 92ms/step - loss: 0.2909 - accuracy: 0.9167 - val_loss: 1.4014 - val_accuracy: 0.4590
# Epoch 37/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.2775 - accuracy: 0.9208 - val_loss: 1.5021 - val_accuracy: 0.4426
# Epoch 38/100
# 4/4 [==============================] - 0s 100ms/step - loss: 0.2509 - accuracy: 0.9333 - val_loss: 1.5213 - val_accuracy: 0.4262
# Epoch 39/100
# 4/4 [==============================] - 0s 102ms/step - loss: 0.2252 - accuracy: 0.9417 - val_loss: 1.6898 - val_accuracy: 0.4098
# Epoch 40/100
# 4/4 [==============================] - 0s 96ms/step - loss: 0.2421 - accuracy: 0.9125 - val_loss: 1.6448 - val_accuracy: 0.4426
# Epoch 41/100
# 4/4 [==============================] - 0s 98ms/step - loss: 0.2534 - accuracy: 0.9042 - val_loss: 1.7203 - val_accuracy: 0.4262
# Epoch 42/100
# 4/4 [==============================] - 0s 89ms/step - loss: 0.2116 - accuracy: 0.9250 - val_loss: 1.7111 - val_accuracy: 0.4590
# Epoch 43/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.1709 - accuracy: 0.9667 - val_loss: 1.6116 - val_accuracy: 0.4098
# Epoch 44/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.1712 - accuracy: 0.9542 - val_loss: 1.8779 - val_accuracy: 0.3934
# Epoch 45/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.1698 - accuracy: 0.9583 - val_loss: 1.8881 - val_accuracy: 0.4262
# Epoch 46/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.1251 - accuracy: 0.9833 - val_loss: 1.9188 - val_accuracy: 0.4098
# Epoch 47/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.1291 - accuracy: 0.9750 - val_loss: 2.1179 - val_accuracy: 0.4098
# Epoch 48/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.1157 - accuracy: 0.9667 - val_loss: 2.0031 - val_accuracy: 0.4426
# Epoch 49/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.1176 - accuracy: 0.9625 - val_loss: 2.0886 - val_accuracy: 0.4098
# Epoch 50/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.1227 - accuracy: 0.9750 - val_loss: 2.0201 - val_accuracy: 0.4262
# Epoch 51/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0941 - accuracy: 0.9875 - val_loss: 2.2563 - val_accuracy: 0.4426
# Epoch 52/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0993 - accuracy: 0.9708 - val_loss: 2.2225 - val_accuracy: 0.4098
# Epoch 53/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0669 - accuracy: 0.9917 - val_loss: 2.0625 - val_accuracy: 0.4262
# Epoch 54/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0633 - accuracy: 0.9875 - val_loss: 2.1242 - val_accuracy: 0.3934
# Epoch 55/100
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0918 - accuracy: 0.9667 - val_loss: 2.4745 - val_accuracy: 0.3934
# Epoch 56/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0744 - accuracy: 0.9917 - val_loss: 2.4510 - val_accuracy: 0.4098
# Epoch 57/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0639 - accuracy: 0.9917 - val_loss: 2.4318 - val_accuracy: 0.3770
# Epoch 58/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0626 - accuracy: 0.9917 - val_loss: 2.7379 - val_accuracy: 0.4098
# Epoch 59/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0891 - accuracy: 0.9750 - val_loss: 2.4934 - val_accuracy: 0.3934
# Epoch 60/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0696 - accuracy: 0.9833 - val_loss: 2.5644 - val_accuracy: 0.4098
# Epoch 61/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0677 - accuracy: 0.9833 - val_loss: 2.3987 - val_accuracy: 0.4262
# Epoch 62/100
# 4/4 [==============================] - 0s 93ms/step - loss: 0.0617 - accuracy: 0.9875 - val_loss: 2.5449 - val_accuracy: 0.4098
# Epoch 63/100
# 4/4 [==============================] - 0s 93ms/step - loss: 0.0657 - accuracy: 0.9917 - val_loss: 2.5272 - val_accuracy: 0.4590
# Epoch 64/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0440 - accuracy: 0.9958 - val_loss: 2.5476 - val_accuracy: 0.4590
# Epoch 65/100
# 4/4 [==============================] - 0s 90ms/step - loss: 0.0686 - accuracy: 0.9833 - val_loss: 2.5849 - val_accuracy: 0.4262
# Epoch 66/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0461 - accuracy: 0.9917 - val_loss: 2.6299 - val_accuracy: 0.4262
# Epoch 67/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0427 - accuracy: 0.9917 - val_loss: 2.7216 - val_accuracy: 0.4590
# Epoch 68/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0607 - accuracy: 0.9833 - val_loss: 2.6461 - val_accuracy: 0.4262
# Epoch 69/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0542 - accuracy: 0.9792 - val_loss: 2.7433 - val_accuracy: 0.4098
# Epoch 70/100
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0405 - accuracy: 0.9917 - val_loss: 2.6547 - val_accuracy: 0.4426
# Epoch 71/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0403 - accuracy: 0.9958 - val_loss: 2.7187 - val_accuracy: 0.4098
# Epoch 72/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0470 - accuracy: 0.9875 - val_loss: 2.7451 - val_accuracy: 0.4590
# Epoch 73/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0422 - accuracy: 0.9917 - val_loss: 2.8997 - val_accuracy: 0.4098
# Epoch 74/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0330 - accuracy: 0.9958 - val_loss: 2.9403 - val_accuracy: 0.3934
# Epoch 75/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 3.0414 - val_accuracy: 0.4098
# Epoch 76/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0331 - accuracy: 0.9917 - val_loss: 3.4308 - val_accuracy: 0.4098
# Epoch 77/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0267 - accuracy: 0.9958 - val_loss: 3.1858 - val_accuracy: 0.4098
# Epoch 78/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0215 - accuracy: 0.9958 - val_loss: 3.0273 - val_accuracy: 0.4098
# Epoch 79/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0325 - accuracy: 0.9833 - val_loss: 3.1734 - val_accuracy: 0.4098
# Epoch 80/100
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 3.1082 - val_accuracy: 0.4590
# Epoch 81/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0355 - accuracy: 0.9917 - val_loss: 3.2245 - val_accuracy: 0.4426
# Epoch 82/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0307 - accuracy: 0.9958 - val_loss: 3.5865 - val_accuracy: 0.4426
# Epoch 83/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0366 - accuracy: 0.9917 - val_loss: 3.4828 - val_accuracy: 0.4098
# Epoch 84/100
# 4/4 [==============================] - 0s 93ms/step - loss: 0.0298 - accuracy: 0.9917 - val_loss: 3.4210 - val_accuracy: 0.4098
# Epoch 85/100
# 4/4 [==============================] - 0s 120ms/step - loss: 0.0336 - accuracy: 0.9958 - val_loss: 3.4893 - val_accuracy: 0.3934
# Epoch 86/100
# 4/4 [==============================] - 1s 126ms/step - loss: 0.0494 - accuracy: 0.9833 - val_loss: 3.1316 - val_accuracy: 0.4262
# Epoch 87/100
# 4/4 [==============================] - 0s 123ms/step - loss: 0.0442 - accuracy: 0.9917 - val_loss: 3.2221 - val_accuracy: 0.4590
# Epoch 88/100
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0384 - accuracy: 0.9917 - val_loss: 3.4018 - val_accuracy: 0.4262
# Epoch 89/100
# 4/4 [==============================] - 0s 119ms/step - loss: 0.0418 - accuracy: 0.9875 - val_loss: 2.9234 - val_accuracy: 0.4426
# Epoch 90/100
# 4/4 [==============================] - 1s 127ms/step - loss: 0.0414 - accuracy: 0.9875 - val_loss: 3.0992 - val_accuracy: 0.4590
# Epoch 91/100
# 4/4 [==============================] - 0s 98ms/step - loss: 0.0468 - accuracy: 0.9833 - val_loss: 2.9735 - val_accuracy: 0.4426
# Epoch 92/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 3.0705 - val_accuracy: 0.4590
# Epoch 93/100
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 3.6719 - val_accuracy: 0.4262
# Epoch 94/100
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0301 - accuracy: 0.9917 - val_loss: 3.6325 - val_accuracy: 0.4590
# Epoch 95/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0310 - accuracy: 0.9917 - val_loss: 3.7050 - val_accuracy: 0.4918
# Epoch 96/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0296 - accuracy: 0.9917 - val_loss: 3.5665 - val_accuracy: 0.4590
# Epoch 97/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0232 - accuracy: 0.9917 - val_loss: 3.3243 - val_accuracy: 0.4426
# Epoch 98/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 3.3388 - val_accuracy: 0.4590
# Epoch 99/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0279 - accuracy: 0.9958 - val_loss: 3.5916 - val_accuracy: 0.4262
# Epoch 100/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0226 - accuracy: 0.9958 - val_loss: 3.6925 - val_accuracy: 0.4426
# Saved model to disk
# INFO:tensorflow:Assets written to: CNN.model\assets
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# '00:00:51'
